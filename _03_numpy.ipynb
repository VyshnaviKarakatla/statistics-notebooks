# %%
#Numpy

# %%
import numpy as np

# %%
arr1=np.array([10,20,30,40,50])
arr1
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr1.shape
# Out:
# (5,)

# %%
arr1.size
# Out:
# 5

# %%
#Indexing
arr1[0]
# Out:
# np.int64(40)

# %%
arr1[3]
# Out:
# np.int64(40)

# %%
arr1[-2]
# Out:
# np.int64(40)

# %%
#Slicing
arr1[2:4]
# Out:
# array([30, 40])

# %%
arr1[::-1]
# Out:
# array([50, 40, 30, 20, 10])

# %%
#We can do all above with lists too
#List VS Numpy array
    Array is faster than list
    Array will take less memo
